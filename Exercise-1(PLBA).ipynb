# %% [markdown]
# **Name: Taha Basharat**
#
# **Roll No: FA24-BBA-084**
#
# **Exercise # 1**

# %%
name=("Taha Basharat")
print(name)
# Out:
# Taha Basharat

# %%
# 2. Store two numbers in variables a and b, then print their sum
a=55
b=77
print("Sum:",a+b)
# Out:
# Sum: 132

# %%
# 3. Create one integer and one float variable, then display their data types
num1=7
num2=7.5
print("Data Types:",type(num1),type(num2))
# Out:
# Data Types: <class 'int'> <class 'float'>

# %%
# 4. Store the string "Hello, Python" in a variable and print its length
msg=("Hello, Python")
print("Length of msg:",len(msg))
# Out:
# Length of msg: 13

# %%
# 5. Assign a number to a variable x and print its square
x=10
print("Square of x:",x**2)
# Out:
# Square of x: 100

# %%
# 6. Take input from the user and display its data type
user_input=input("Enter something")
print("Data type of input:",type(user_input))
# Out:
# Data type of input: <class 'str'>

# %%
# 7. Store a boolean value and check whether it is True or not
lie=False
print("Boolean lie is false:", lie==False)
# Out:
# Boolean lie is false: True

# %%
# 8. Use f-string to print your name and age
age=20
print(f"My name is {name} and i am {age} years old.")
# Out:
# My name is Taha Basharat and i am 20 years old.

# %%
# 9. Convert an integer variable to a float and print
x=10
x=float(x)
print("Converted to float:",x)
# Out:
# Converted to float: 10.0

# %%
# 10. Create a complex number and print its real and imaginary parts
x=7+9j
print("Complex number:",x)
print("Real part:",x.real)
print("Imaginary part:",x.imag)
# Out:
# Complex number: (7+9j)
# Real part: 7.0
# Imaginary part: 9.0

# %%
# 11. Perform arithmetic operations
x,y=13,8
print("Addition:",x+y)
print("Subtraction:",x-y)
print("Multiplication:",x*y)
print("Division:",x/y)
# Out:
# Addition: 21
# Subtraction: 5
# Multiplication: 104
# Division: 1.625

# %%
# 12. Floor division
print("Floor Division:",x//y)
# Out:
# Floor Division: 1

# %%
# 13. Use the modulus operator (%) to find the remainder of two numbers.
x=11
y=66
print("Reminder:",x % y)
# Out:
# Reminder: 11

# %%
# 14. Use the exponentiation operator (**) to calculate the power of a number.
print("Power:",x**y)
# Out:
# Power: 539407797827634189900210968137750826278309533633974732577186113975161

# %%
# 15. Use comparison operators (>, <, ==, !=) to compare two variables.
print("x<y:",x<y)
print("x!=y:",x!=y)
print("x==y:",x==y)
print("x>y:",x>y)
# Out:
# x<y: True
# x!=y: True
# x==y: False
# x>y: False

# %%
# 16. Use logical operators (and, or, not) to test a condition.
print("x>6 and y>6:",x>6 and y>6)
print("not(x<5):",not(x<5))
# Out:
# x>6 and y>6: True
# not(x<5): True

# %%
# 17. Write an expression that demonstrates operator precedence in Python.
result=5+6*4
print("Operater precedence result:",result)
# Out:
# Operater precedence result: 29

# %%
# 18. Use compound assignment operators (+=, -=) in a short program.
a=6
a +=4
a -=3
print("After compound assignment:",a)
# Out:
# After compound assignment: 7

# %%
# 19. Take two numbers from the user and calculate their average
n1=50
n2=20
average=(n1+n2)/2
print("Average:",average)
# Out:
# Average: 35.0

# %%
# 20. Use a conditional expression (ternary operator) to check if a number is even or odd.
num=6
if num % 2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
# 21. Check positive, negative or zero
num = -3
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Negative

# %%
# 22. Check if number is even or odd
num = 9
if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %%
# 23. Check adult or minor
age = 33
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %%
# 24. Largest of three numbers
a, b, c = 12, 25, 9
print("Largest:", max(a, b, c))
# Out:
# Largest: 25

# %%
# 25. Grade based on marks
marks = 85
if marks >= 90:
    grade = "A"
elif marks >= 80:
    grade = "B"
elif marks >= 70:
    grade = "C"
elif marks >= 60:
    grade = "D"
else:
    grade = "F"
print("Grade:", grade)
# Out:
# Grade: B

# %%
# 26. Leap year check
year = 2024
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Leap Year

# %%
# 27. Temperature check
temp = 30
if temp > 35:
    print("Hot")
elif temp >= 20:
    print("Warm")
else:
    print("Cold")
# Out:
# Warm

# %%
# 28. Password checking
password = "admin123"
entered = "admin123"
if entered == password:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Granted

# %%
# 29. Vowel or consonant
char = "a"
if char.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Vowel

# %%
# 30. Day of week (1–7)
day = 3
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Day:", days[day - 1])
# Out:
# Day: Wednesday

# %%
# 31. Create list of fruits and print it
fruits = ["apple", "banana", "cherry"]
print("Fruits:", fruits)
# Out:
# Fruits: ['apple', 'banana', 'cherry']

# %%
# 32. Add & remove element
fruits.append("mango")
fruits.remove("banana")
print("After Append & Remove:", fruits)
# Out:
# After Append & Remove: ['apple', 'cherry', 'mango']

# %%
# 33. Sum of numbers in list
numbers = [10, 20, 30, 40]
print("Sum:", sum(numbers))
# Out:
# Sum: 100

# %%
# 34. Max & Min in list
print("Max:", max(numbers))
print("Min:", min(numbers))
# Out:
# Max: 40
# Min: 10

# %%
# 35. Slicing
print("First 3:", numbers[:3])
print("Last 3:", numbers[-3:])
# Out:
# First 3: [10, 20, 30]
# Last 3: [20, 30, 40]

# %%
# 36. Replace element
numbers[1] = 25
print("After Replace:", numbers)
# Out:
# After Replace: [10, 25, 30, 40]

# %%
# 37. Reverse list
numbers.reverse()
print("Reversed:", numbers)
# Out:
# Reversed: [40, 30, 25, 10]

# %%
# 38. Count occurrences
numbers.append(25)
print("Count of 25:", numbers.count(25))
# Out:
# Count of 25: 2

# %%
# 39. Concatenate two lists
list1 = [1, 2, 3]
list2 = [4, 5]
combined = list1 + list2
print("Concatenated List:", combined)
# Out:
# Concatenated List: [1, 2, 3, 4, 5]

# %%
# 40. List comprehension (squares)
squares = [x**2 for x in range(1, 11)]
print("Squares 1–10:", squares)
# Out:
# Squares 1–10: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# 41. Tuple creation
tup = (10, 20, 30)
print("Tuple:", tup)
# Out:
# Tuple: (10, 20, 30)

# %%
# 42. Tuple unpacking
a, b, c = tup
print("Unpacked:", a, b, c)
# Out:
# Unpacked: 10 20 30

# %%
# 43. Index and count in tuple
print("Index of 20:", tup.index(20))
print("Count of 10:", tup.count(10))
# Out:
# Index of 20: 1
# Count of 10: 1

# %%
# 44. Convert tuple to list, modify, back to tuple
temp_list = list(tup)
temp_list[1] = 99
tup = tuple(temp_list)
print("Modified Tuple:", tup)
# Out:
# Modified Tuple: (10, 99, 30)

# %%
# 45. Concatenate tuples
tup2 = (40, 50)
combined_tup = tup + tup2
print("Concatenated Tuple:", combined_tup)

print("\n--- All Exercises Completed Successfully ---")
# Out:
# Concatenated Tuple: (10, 99, 30, 40, 50)
#
# --- All Exercises Completed Successfully ---
